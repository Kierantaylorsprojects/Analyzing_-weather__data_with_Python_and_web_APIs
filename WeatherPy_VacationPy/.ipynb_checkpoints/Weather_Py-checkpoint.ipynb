# %% [markdown]
# # WeatherPy

# %% [markdown]
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ## Generate the Cities List by Using the citipy Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
# ## Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{query_url}&q={city.replace(' ', '+')}"
        
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%m/%d/%y,%H:%M:%S")
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | allapalli
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | hualmay
# Processing Record 5 of Set 1 | mocuba
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | san patricio
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | leshukonskoye
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | kudahuvadhoo
# Processing Record 24 of Set 1 | khatanga
# Processing Record 25 of Set 1 | srebrenica
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | aden
# Processing Record 29 of Set 1 | narsaq
# Processing Record 30 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 1 | naze
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | chokurdakh
# Processing Record 35 of Set 1 | kimparana
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | el badari
# City not found. Skipping...
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | goksun
# Processing Record 41 of Set 1 | aklavik
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | mecca
# Processing Record 44 of Set 1 | talnakh
# Processing Record 45 of Set 1 | zhicheng
# Processing Record 46 of Set 1 | juye
# Processing Record 47 of Set 1 | saint anthony
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | ilulissat
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 0 of Set 2 | anderson
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | klaksvik
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | margate
# Processing Record 5 of Set 2 | uhlove
# Processing Record 6 of Set 2 | codrington
# Processing Record 7 of Set 2 | svetlogorsk
# Processing Record 8 of Set 2 | ambilobe
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | saldanha
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | jasper
# Processing Record 14 of Set 2 | chapada dos guimaraes
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | vega de alatorre
# Processing Record 18 of Set 2 | luderitz
# Processing Record 19 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | lavrentiya
# Processing Record 25 of Set 2 | san ramon
# Processing Record 26 of Set 2 | alpena
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | sinnamary
# Processing Record 29 of Set 2 | malko tarnovo
# Processing Record 30 of Set 2 | phangnga
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | akureyri
# Processing Record 35 of Set 2 | pouebo
# Processing Record 36 of Set 2 | goderich
# Processing Record 37 of Set 2 | marawi
# Processing Record 38 of Set 2 | itaueira
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | tupik
# Processing Record 41 of Set 2 | bubaque
# Processing Record 42 of Set 2 | dunedin
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | rafai
# Processing Record 45 of Set 2 | galle
# Processing Record 46 of Set 2 | inta
# Processing Record 47 of Set 2 | baghdad
# Processing Record 48 of Set 2 | bati
# Processing Record 49 of Set 2 | avera
# Processing Record 0 of Set 3 | zambezi
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | urfa
# City not found. Skipping...
# Processing Record 4 of Set 3 | asau
# Processing Record 5 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 3 | vieques
# Processing Record 7 of Set 3 | joshimath
# Processing Record 8 of Set 3 | alekseyevka
# Processing Record 9 of Set 3 | gazalkent
# Processing Record 10 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 3 | chico
# Processing Record 12 of Set 3 | college
# Processing Record 13 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | victoria
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | chapais
# Processing Record 18 of Set 3 | poum
# Processing Record 19 of Set 3 | sabha
# Processing Record 20 of Set 3 | luba
# Processing Record 21 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 3 | tual
# Processing Record 23 of Set 3 | miyako
# Processing Record 24 of Set 3 | port blair
# Processing Record 25 of Set 3 | zhigansk
# Processing Record 26 of Set 3 | mariental
# Processing Record 27 of Set 3 | bo
# City not found. Skipping...
# Processing Record 28 of Set 3 | sanmenxia
# Processing Record 29 of Set 3 | fort dodge
# Processing Record 30 of Set 3 | semirara
# Processing Record 31 of Set 3 | geraldton
# Processing Record 32 of Set 3 | nyurba
# Processing Record 33 of Set 3 | ust-nera
# Processing Record 34 of Set 3 | yusva
# City not found. Skipping...
# Processing Record 35 of Set 3 | la macarena
# Processing Record 36 of Set 3 | la ronge
# Processing Record 37 of Set 3 | pangai
# Processing Record 38 of Set 3 | yar-sale
# Processing Record 39 of Set 3 | vila velha
# Processing Record 40 of Set 3 | amapa
# Processing Record 41 of Set 3 | hearst
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | pag
# Processing Record 44 of Set 3 | kamenka
# Processing Record 45 of Set 3 | sept-iles
# Processing Record 46 of Set 3 | zhigalovo
# Processing Record 47 of Set 3 | kuloy
# Processing Record 48 of Set 3 | mandalgovi
# Processing Record 49 of Set 3 | mount isa
# Processing Record 0 of Set 4 | cristalina
# Processing Record 1 of Set 4 | pangnirtung
# Processing Record 2 of Set 4 | clyde river
# Processing Record 3 of Set 4 | mar del plata
# Processing Record 4 of Set 4 | broome
# Processing Record 5 of Set 4 | nawa
# Processing Record 6 of Set 4 | neuquen
# Processing Record 7 of Set 4 | northam
# Processing Record 8 of Set 4 | tuktoyaktuk
# Processing Record 9 of Set 4 | lithgow
# Processing Record 10 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 4 | koboldo
# City not found. Skipping...
# Processing Record 12 of Set 4 | juneau
# Processing Record 13 of Set 4 | kosum phisai
# Processing Record 14 of Set 4 | kamaishi
# Processing Record 15 of Set 4 | mastic beach
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | zurrieq
# Processing Record 18 of Set 4 | tiznit
# Processing Record 19 of Set 4 | bara
# Processing Record 20 of Set 4 | norman wells
# Processing Record 21 of Set 4 | salisbury
# Processing Record 22 of Set 4 | abha
# Processing Record 23 of Set 4 | honiara
# Processing Record 24 of Set 4 | alanya
# Processing Record 25 of Set 4 | goundam
# Processing Record 26 of Set 4 | tilichiki
# Processing Record 27 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | shahr-e kord
# Processing Record 30 of Set 4 | berlevag
# Processing Record 31 of Set 4 | vulcan
# Processing Record 32 of Set 4 | faranah
# Processing Record 33 of Set 4 | parras
# City not found. Skipping...
# Processing Record 34 of Set 4 | shirdi
# Processing Record 35 of Set 4 | karratha
# Processing Record 36 of Set 4 | alyangula
# Processing Record 37 of Set 4 | bambous virieux
# Processing Record 38 of Set 4 | hasaki
# Processing Record 39 of Set 4 | mitu
# Processing Record 40 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | moranbah
# Processing Record 44 of Set 4 | lorengau
# Processing Record 45 of Set 4 | media luna
# Processing Record 46 of Set 4 | al
# City not found. Skipping...
# Processing Record 47 of Set 4 | yuci
# Processing Record 48 of Set 4 | raymondville
# Processing Record 49 of Set 4 | ponta do sol
# Processing Record 0 of Set 5 | castro
# Processing Record 1 of Set 5 | juquia
# Processing Record 2 of Set 5 | bahia blanca
# Processing Record 3 of Set 5 | bredasdorp
# Processing Record 4 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 5 of Set 5 | nome
# Processing Record 6 of Set 5 | rawson
# Processing Record 7 of Set 5 | sur
# Processing Record 8 of Set 5 | busca
# Processing Record 9 of Set 5 | biltine
# Processing Record 10 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 11 of Set 5 | christchurch
# Processing Record 12 of Set 5 | puerto narino
# Processing Record 13 of Set 5 | byron bay
# Processing Record 14 of Set 5 | wanxian
# Processing Record 15 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 16 of Set 5 | gaziantep
# Processing Record 17 of Set 5 | noumea
# Processing Record 18 of Set 5 | grindavik
# Processing Record 19 of Set 5 | batagay-alyta
# Processing Record 20 of Set 5 | kidal
# Processing Record 21 of Set 5 | baker city
# Processing Record 22 of Set 5 | yulara
# Processing Record 23 of Set 5 | hyderabad
# Processing Record 24 of Set 5 | yeppoon
# Processing Record 25 of Set 5 | north bend
# Processing Record 26 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 5 | zaraza
# Processing Record 28 of Set 5 | egvekinot
# Processing Record 29 of Set 5 | lagoa
# Processing Record 30 of Set 5 | aldan
# Processing Record 31 of Set 5 | katangli
# Processing Record 32 of Set 5 | yerbogachen
# Processing Record 33 of Set 5 | rundu
# Processing Record 34 of Set 5 | tuatapere
# Processing Record 35 of Set 5 | port-gentil
# Processing Record 36 of Set 5 | cape coast
# Processing Record 37 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 5 | vaitape
# Processing Record 39 of Set 5 | mashhad
# Processing Record 40 of Set 5 | penzance
# Processing Record 41 of Set 5 | rudnogorsk
# Processing Record 42 of Set 5 | nizhniy kuranakh

# %%
# Convert the cities weather data into a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("./plt_folder/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("./plt_folder/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ## Create the Scatter Plots Requested
# ## Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.title(f"City Latitude vs Max Temperature" + '(' + str(pd.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Temperature (C)")

# Save the figure
plt.savefig("./plt_folder/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

plt.scatter(city_data_df["Lat"],city_data_df["Humidity"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity"  + '(' + str(pd.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("./plt_folder/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness"  + '(' + str(pd.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("./plt_folder/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed"  + '(' + str(pd.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("./plt_folder/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearregression(x, y):
    (slope, intercept, r, p, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    plt.plot(x_values,regress_values, color='darkred', linewidth=2)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.DataFrame(city_data_df[city_data_df['Lat'] >= 0])

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.DataFrame(city_data_df[city_data_df['Lat'] < 0])

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ## Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Build scatter plot for each data type
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Max Temp vs. Latitude'  + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Max Temperature (C)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(1, -50), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('./plt_folder/Fig5.png')

# Show plot:
plt.show()

# %%
# Linear regression on Southern Hemisphere

# Build scatter plot for each data type
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Max Temp vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Max Temperature (C)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(-55, 30), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('./plt_folder/Fig6.png')

# Show plot:
plt.show()

# %% [markdown]
# ### Discussion about the linear relationship:
#
# The cities in the Northern Hemisphere have a moderately strong linear relationship between their max temp and latitude as shown by the value of 0.67.
#
# The the cities in the Southern Hemisphere have a minimal linear relationship between their max temp and latitude as shown by the value of 0.15.

# %% [markdown]
# ## Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Build scatter plot for each data type
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Humidity vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(45, 15), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('./plt_folder/Fig7.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# Build scatter plot for each data type
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Humidity vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(-18, 20), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('./plt_folder/Fig8.png')

# Show plot:
plt.show()

# %% [markdown]
# ### Discussion about the linear relationship:
#
# The Northern Hemisphere had a value of 0.21 and the Southern Hemisphere had a value of 0.11.
#
# This shows a moderate minimal relationship.

# %% [markdown]
# ## Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Cloudiness vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(55, 15), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('./plt_folder/Fig9.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# Build scatter plot for each data type
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Cloudiness vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(-18, 4), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('./plt_folder/Fig10.png')

# Show plot:
plt.show()

# %% [markdown]
# ## Discussion about the linear relationship:
#
# The Northern Hemisphere had a value of 0.07 and the Southern Hemisphere had a value of 0.14.
#
# This shows a minimal linear relationship.

# %% [markdown]
# ## Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Wind Speed vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Wind Speed (m/s)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(45, 15), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('./plt_folder/Fig11.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# Build scatter plot for each data type
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Wind Speed vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Wind Speed (m/s)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(-30, 10), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('./plt_folder/Fig12.png')

# Show plot:
plt.show()

# %% [markdown]
# ## Discussion about the linear relationship:
#
# The Northern Hemisphere had a value of 0.00 and the Southern Hemisphere had a value of 0.12.
#
# This shows a minimal linear relationship.
