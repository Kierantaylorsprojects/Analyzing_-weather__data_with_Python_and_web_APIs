# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import matplotlib.pyplot as plt
import numpy as np
import os
import json
import gmaps
import warnings
warnings.filterwarnings('ignore')

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("./plt_folder/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  constantine  36.3650    6.6147      0.67        93          20
# 1        1       dankov  53.2515   39.1555    -12.38        97          65
# 2        2     linhares -19.3911  -40.0722     22.45        96         100
# 3        3     katsuura  35.1333  140.3000     11.01        92         100
# 4        4   shimanovsk  52.0000  127.7000    -10.41        69          91
#
#    Wind Speed Country               Date
# 0        1.03      DZ  02/13/23,04:23:10
# 1        2.86      RU  02/13/23,04:23:11
# 2        1.05      BR  02/13/23,04:23:11
# 3        6.64      JP  02/13/23,04:23:12
# 4        5.80      RU  02/13/23,04:23:12

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_humidity_map = city_data_df.hvplot.points("Lng", 
                                          "Lat", 
                                          geo = True, 
                                          tiles = "OSM", 
                                          frame_width = 800, 
                                          frame_height = 600, 
                                          size = "Humidity", 
                                          scale = 1, 
                                          color = "City", 
                                          hover_cols = ["City", "Hotel Name", "Country"])

# Display the map
city_humidity_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather_cities = city_data_df[(city_data_df['Max Temp'] < 14) &
                             (city_data_df['Max Temp'] > 5) &
                             (city_data_df['Wind Speed'] < 10) &
                             (city_data_df['Cloudiness'] < 40)]

# Drop any rows with null values
ideal_weather_cities = ideal_weather_cities.dropna() 

# Display sample data
ideal_weather_cities
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 12        12                 eureka  40.8021 -124.1637      7.74        93
# 47        47              follonica  42.9263   10.7616      9.17        66
# 76        76                  birin  26.8865   88.0718     13.47        44
# 116      116                 tecpan  14.7623  -90.9947     10.49        97
# 141      141                mattoon  39.4831  -88.3728      5.97        42
# 142      142                  ancud -41.8697  -73.8203     11.37        69
# 162      162           port hueneme  34.1478 -119.1951     11.58        75
# 163      163  los llanos de aridane  28.6585  -17.9182     12.86        63
# 180      180                  ginda  30.6945   78.4932     13.61        19
# 186      186                fortuna  40.5982 -124.1573      7.59        94
# 187      187              tucumcari  35.1717 -103.7250      6.91        36
# 225      225          half moon bay  37.4636 -122.4286     12.95        74
# 232      232               hamilton  39.1834  -84.5333      5.99        47
# 235      235                 bethel  41.3712  -73.4140      5.20        56
# 240      240     comodoro rivadavia -45.8667  -67.5000     13.92        35
# 264      264                margate  51.3813    1.3862      6.50        78
# 281      281                tazmalt  36.3868    4.3989      5.75        84
# 283      283              san ramon  37.7799 -121.9780     12.50        76
# 322      322              dickinson  29.4608  -95.0513     12.97        87
# 325      325               ajdabiya  30.7554   20.2263      9.74        67
# 329      329             miram shah  33.0086   70.0697     10.73        25
# 339      339               carthage  36.8611   10.3316      9.74        76
# 342      342           stephenville  32.2207  -98.2023     11.07        39
# 368      368                 bastia  42.6667    9.3333      8.50        74
# 370      370                 banepa  27.6298   85.5214     11.18        58
# 381      381                  selma  36.5708 -119.6121      9.95        93
# 386      386            sao joaquim -28.2939  -49.9317     12.79        98
# 235                 bethel      US  41.3712  -73.4140        56
# 240     comodoro rivadavia      AR -45.8667  -67.5000        35
# 264                margate      GB  51.3813    1.3862        78
# 281                tazmalt      DZ  36.3868    4.3989        84
# 283              san ramon      US  37.7799 -121.9780        76
# 322              dickinson      US  29.4608  -95.0513        87
# 325               ajdabiya      LY  30.7554   20.2263        67
# 329             miram shah      PK  33.0086   70.0697        25
# 339               carthage      TN  36.8611   10.3316        76
# 342           stephenville      US  32.2207  -98.2023        39
# 368                 bastia      FR  42.6667    9.3333        74
# 370                 banepa      NP  27.6298   85.5214        58
# 381                  selma      US  36.5708 -119.6121        93
# 386            sao joaquim      BR -28.2939  -49.9317        98
# 408                 naples      IT  40.8333   14.2500        64
# 417              neerijnen      NL  51.8317    5.2819        83
# 430              kathmandu      NP  27.7167   85.3167        58
# 438                calbuco      CL -41.7680  -73.1273        72
# 496           saint george      US  37.1041 -113.5841        40
# 530                   jalu      LY  29.0331   21.5482        62
# 533          harrisonville      US  38.6533  -94.3488        58
# 535                dickson      US  36.0770  -87.3878        41

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = ["accommodation.hotel"]
params = {
    "categories": categories,
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    long = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{long},{lat},{radius}"
    params["bias"] = f"proximity:{long},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
  
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError) as err:
        print(err)
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# 'features'
# eureka - nearest hotel: No hotel found
# 'features'
# follonica - nearest hotel: No hotel found
# 'features'
# birin - nearest hotel: No hotel found
# 'features'
# tecpan - nearest hotel: No hotel found
# 'features'
# mattoon - nearest hotel: No hotel found
# 'features'
# ancud - nearest hotel: No hotel found
# 'features'
# port hueneme - nearest hotel: No hotel found
# 'features'
# los llanos de aridane - nearest hotel: No hotel found
# 'features'
# ginda - nearest hotel: No hotel found
# 'features'
# fortuna - nearest hotel: No hotel found
# 'features'
# tucumcari - nearest hotel: No hotel found
# 'features'
# half moon bay - nearest hotel: No hotel found
# 'features'
# hamilton - nearest hotel: No hotel found
# 'features'
# bethel - nearest hotel: No hotel found
# 'features'
# comodoro rivadavia - nearest hotel: No hotel found
# 'features'
# margate - nearest hotel: No hotel found
# 'features'
# tazmalt - nearest hotel: No hotel found
# 'features'
# san ramon - nearest hotel: No hotel found
# 'features'
# dickinson - nearest hotel: No hotel found
# 'features'
# ajdabiya - nearest hotel: No hotel found
# 'features'
# miram shah - nearest hotel: No hotel found
# 'features'
# carthage - nearest hotel: No hotel found
# 'features'
# stephenville - nearest hotel: No hotel found
# 'features'
# bastia - nearest hotel: No hotel found
# 'features'
# banepa - nearest hotel: No hotel found
# 'features'
# selma - nearest hotel: No hotel found
# 'features'
# sao joaquim - nearest hotel: No hotel found
# 'features'
# naples - nearest hotel: No hotel found
# 'features'
# neerijnen - nearest hotel: No hotel found
# 'features'
# kathmandu - nearest hotel: No hotel found
# 'features'
# calbuco - nearest hotel: No hotel found
# 'features'
# saint george - nearest hotel: No hotel found
# 'features'
# jalu - nearest hotel: No hotel found
# 'features'
# harrisonville - nearest hotel: No hotel found
# 'features'
# dickson - nearest hotel: No hotel found
#                       City Country      Lat       Lng  Humidity  \
# 12                  eureka      US  40.8021 -124.1637        93
# 47               follonica      IT  42.9263   10.7616        66
# 76                   birin      NP  26.8865   88.0718        44
# 116                 tecpan      GT  14.7623  -90.9947        97
# 141                mattoon      US  39.4831  -88.3728        42
# 142                  ancud      CL -41.8697  -73.8203        69
# 162           port hueneme      US  34.1478 -119.1951        75
# 163  los llanos de aridane      ES  28.6585  -17.9182        63
# 180                  ginda      IN  30.6945   78.4932        19
# 186                fortuna      US  40.5982 -124.1573        94
# 187              tucumcari      US  35.1717 -103.7250        36
# 225          half moon bay      US  37.4636 -122.4286        74
# 232               hamilton      US  39.1834  -84.5333        47
# 235                 bethel      US  41.3712  -73.4140        56
# 240     comodoro rivadavia      AR -45.8667  -67.5000        35
# 264                margate      GB  51.3813    1.3862        78
# 281                tazmalt      DZ  36.3868    4.3989        84
# 283              san ramon      US  37.7799 -121.9780        76
# 322              dickinson      US  29.4608  -95.0513        87
# 325               ajdabiya      LY  30.7554   20.2263        67
# 329             miram shah      PK  33.0086   70.0697        25
# 339               carthage      TN  36.8611   10.3316        76
# 342           stephenville      US  32.2207  -98.2023        39
# 368                 bastia      FR  42.6667    9.3333        74
# 370                 banepa      NP  27.6298   85.5214        58
# 381                  selma      US  36.5708 -119.6121        93
# 386            sao joaquim      BR -28.2939  -49.9317        98
# 408                 naples      IT  40.8333   14.2500        64
# 417              neerijnen      NL  51.8317    5.2819        83
# 430              kathmandu      NP  27.7167   85.3167        58
# 438                calbuco      CL -41.7680  -73.1273        72
# 496           saint george      US  37.1041 -113.5841        40
# 530                   jalu      LY  29.0331   21.5482        62
# 533          harrisonville      US  38.6533  -94.3488        58
# 535                dickson      US  36.0770  -87.3878        41
#
#          Hotel Name
# 12   No hotel found
# 47   No hotel found
# 76   No hotel found
# 116  No hotel found
# 141  No hotel found
# 142  No hotel found
# 162  No hotel found
# 163  No hotel found
# 180  No hotel found
# 186  No hotel found
# 187  No hotel found
# 225  No hotel found
# 232  No hotel found
# 235  No hotel found
# 240  No hotel found
# 264  No hotel found
# 281  No hotel found
# 283  No hotel found
# 322  No hotel found
# 325  No hotel found
# 329  No hotel found
# 339  No hotel found
# 342  No hotel found
# 368  No hotel found
# 370  No hotel found
# 381  No hotel found
# 386  No hotel found
# 408  No hotel found
# 417  No hotel found
# 430  No hotel found
# 438  No hotel found
# 496  No hotel found
# 530  No hotel found
# 533  No hotel found
# 535  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
ideal_cities_map = hotel_df.hvplot.points("Lng", 
                                          "Lat", 
                                          geo = True, 
                                          tiles = "OSM", 
                                          frame_width = 800, 
                                          frame_height = 600, 
                                          size = "Humidity", 
                                          scale = 1, 
                                          color = "City", 
                                          hover_cols = ["City", "Hotel Name", "Country"])

# Display the map
ideal_cities_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
